# %% [markdown]
# <a href="https://colab.research.google.com/github/hpatel1998/CRUD_Hitakshi/blob/main/Prepared%20dashboard%20dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
mkdir dataset

# %%
from bing_image_downloader import downloader
downloader.download("Various dashboards", limit=100,  output_dir='dataset', adult_filter_off=True, force_replace=False, timeout=60)
# Out:
# [%] Downloading Images to /content/dataset/Various dashboards
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://webapphuddle.com/wp-content/uploads/2015/01/6.ipad_dashboard.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.geckoboard.com/uploads/sales-dashboard-example.png
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://plecto-website-2020.s3.amazonaws.com/images/mock_ceo_dashboard_RESIZED_FINAL_1.max-1280x960.png
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://plecto-website-2020.s3.amazonaws.com/images/types_of_dashboard_fi.ecdc0cf6.fill-1200x625.format-jpeg.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://ubiq.co/analytics-blog/wp-content/uploads/2020/02/customer-service-dashboard.png
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://cdn.technologyadvice.com/wp-content/uploads/2015/06/gooddata-dashboard.png
# ...
